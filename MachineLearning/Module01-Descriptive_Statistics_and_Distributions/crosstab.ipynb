# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Example data
df = pd.DataFrame({
    'gender': ['Male', 'Female', 'Male', 'Female', 'Male'],
    'smoker': ['Yes', 'No', 'No', 'Yes', 'Yes']
})

# Crosstab
ct = pd.crosstab(df['gender'], df['smoker'])
print(ct)
sns.heatmap(ct, annot=True, cmap="Blues")
plt.title("Gender vs Smoker Crosstab")
plt.show()
# Out:
# smoker  No  Yes
# gender
# Female   1    1
# Male     1    2

# %%
sns.countplot(data=df, x='gender', hue='smoker')
plt.title("Countplot (like Crosstab)")
plt.show()
